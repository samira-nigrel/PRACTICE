# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv',index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.shape#gives no of rows and cols in tuple form
# Out:
# (64461, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %% [markdown]
# pd.set_option('display.max_columns',61)

# %%
schema_df=pd.read_csv('survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
pd.set_option('display.max_rows',61)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.tail()
# Out:
#            MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# Respondent
# 64858             NaN      Yes  NaN         16      NaN        NaN
# 64867             NaN      Yes  NaN        NaN      NaN        NaN
# 64898             NaN      Yes  NaN        NaN      NaN        NaN
# 64925             NaN      Yes  NaN        NaN      NaN        NaN
# 65112             NaN      Yes  NaN        NaN      NaN        NaN
#
#             ConvertedComp        Country CurrencyDesc CurrencySymbol  ...  \
# Respondent                                                            ...
# 64858                 NaN  United States          NaN            NaN  ...
# 64867                 NaN        Morocco          NaN            NaN  ...
# 64898                 NaN       Viet Nam          NaN            NaN  ...
# 64925                 NaN         Poland          NaN            NaN  ...
# 65112                 NaN          Spain          NaN            NaN  ...
#
# ...

# %%
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 1                     EUR  ...  Neither easy nor difficult
# 2                     GBP  ...                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# ...

# %%
people={'first':["samira","gaurav","svara"],
        'last':["n","k","k"],
        'email':["sam@abc.com",'gk@abc.com','s@abc.com']
       }

# %%
people
# Out:
# {'first': ['samira', 'gaurav', 'svara'],
#  'last': ['n', 'k', 'k'],
#  'email': ['sam@abc.com', 'gk@abc.com', 's@abc.com']}

# %%
df_p =pd.DataFrame(people)

# %%
df_p
# Out:
#     first last        email
# 0  samira    n  sam@abc.com
# 1  gaurav    k   gk@abc.com
# 2   svara    k    s@abc.com

# %%
df_p['last']  #df.last
# Out:
# 0    n
# 1    k
# 2    k
# Name: last, dtype: object

# %%
type(df_p['last'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# - dataframe is rows and column (container for multiple series)
# - series is rows of data(single column of rows)

# %%
df_p[['first','last']]
# Out:
#     first last
# 0  samira    n
# 1  gaurav    k
# 2   svara    k

# %%
df_p.iloc[0]#iloc is index location
# Out:
# first         samira
# last               n
# email    sam@abc.com
# Name: 0, dtype: object

# %%
df_p.iloc[[0,1],1]# allowas selection of rows and columns
# Out:
# 0    n
# 1    k
# Name: last, dtype: object

# %%
df_p.loc#loc allows selection by labels

# %%
df_p.loc[[0,1],'last']
# Out:
# 0    n
# 1    k
# Name: last, dtype: object

# %%
df_p.loc[[0,1],['last','first']]
# Out:
#   last   first
# 0    n  samira
# 1    k  gaurav

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[[0,1,2],'Hobbyist']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-eec43726d053> in <module>
# ----> 1 df.loc[[0,1,2],'Hobbyist']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#    1419                     return section
# ...

# %%
df.loc[0:2,'Hobbyist':'CompFreq']#start:end both inclusive with loc

# %% [markdown]
# ### Set, Reset, and Use Indexes

# %%
df_p.set_index('email',inplace=True)

# %%
df_p

# %%
df_p.index

# %%
df_p.loc['sam@abc.com','last']#label of index

# %%
df_p.reset_index(inplace=True)

# %%
df_p

# %%
schema_df.index

# %%
schema_df.loc['OpSys','QuestionText']

# %%
schema_df.loc['OpSys']

# %%
schema_df.sort_index(inplace=True)#schema_df.sort_index(ascending=False,inplace=True) 
#make descending sorting permnent inplace=True

# %% [markdown]
# ### Filtering - Using Conditionals to Filter Rows and Columns

# %%
filt =(df_p['last']=='k') #filter mask

# %%
df_p['last']=='k'

# %%
df_p[filt] # df_p[df_p['last']=='k']

# %%
df_p.loc[filt,'email']

# %% [markdown]
# - & and
# - | or
# - ~ not

# %%
filt1 =~((df_p['last']=='k')&(df_p['first']=='svara'))

# %%
df_p.loc[filt1]

# %%
high_sal=(df['ConvertedComp']>30300)

# %%
df.loc[high_sal,['Country','ConvertedComp','WebframeWorkedWith']]

# %%
countries=['United States','United Kingdom','Denmark']

# %%
filt3 =df['Country'].isin(countries)

# %%
df.loc[filt3]

# %%
filt4=df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt4,'LanguageWorkedWith']

# %% [markdown]
# ### Updating Rows and Columns - Modifying Data Within DataFrames

# %%
df_p.columns

# %%
df_p.columns =['first_name','last_name','email']#update all column

# %%
df_p.columns

# %%
df_p.columns = [x.upper() for x in df_p.columns] # all column headers in uppercase

# %%
df_p.columns

# %%
#replace spaces with underscore
df_p.columns =df_p.columns.str.replace('_','')

# %%
df_p.columns = [x.lower() for x in df_p.columns]

# %%
df_p.columns

# %%
df_p.rename(columns={'firstname':'first','lastname':'last'},inplace=True)

# %%
df_p

# %%
#update data in a row
df_p.loc[2]

# %%
df_p.loc[2]=['svara','nk','sv@abc.in']

# %%
df_p

# %%
df_p.loc[2,['last','email']]=['k','svara@abc.in']

# %%
df_p

# %%
df_p.at[2,'last']='kal'

# %%
df_p  # dont use filter to update row value

# %%
filt=(df_p['email']=='svara@abc.in')

# %%
df_p.loc[filt,'last']='k'
df_p

# %%
df_p['email']=df_p['email'].str.lower()
df_p

# %% [markdown]
# - apply
# - applymap
# - map
# - replace

# %%
df_p['email'].apply(len)

# %%
def update_email(email):
    return email.upper()

# %%
df_p['email'].apply(update_email)

# %%
df_p['email']=df_p['email'].apply(update_email)
df_p

# %%
df_p['email']=df_p['email'].apply(lambda x:x.lower())
df_p

# %%
df_p.apply(len)

# %%
len(df_p['email'])

# %%
df_p.apply(pd.Series.min)#better to work with numerical values

# %%
df_p.apply(lambda x : x.min())

# %%
#applymap works only on dataframe
df_p.applymap(len)

# %%
df_p.applymap(str.lower)

# %%
#map works only on series
df_p['first'].map({'samira':'sam','gaurav':'gk'})

# %%
#map works only on series
df_p['first']=df_p['first'].replace({'samira':'sam','gaurav':'gk'})

# %%
df_p
# Out:
#     first last        email
# 0  samira    n  sam@abc.com
# 1  gaurav    k   gk@abc.com
# 2   svara    k    s@abc.com

# %%
df.rename(columns={'ConvertedComp':'salaryUSD'},inplace=True)
df

# %%
df['Hobbyist'].map()

# %% [markdown]
# ### Add/Remove Rows and Columns From DataFrames

# %%
df_p['full_name']=df_p['first']+' ' +df_p['last']
df_p
# Out:
#     first last        email full_name
# 0  samira    n  sam@abc.com  samira n
# 1  gaurav    k   gk@abc.com  gaurav k
# 2   svara    k    s@abc.com   svara k

# %%
df_p.drop(columns=['first','last'],inplace=True)

# %%
df_p['full_name'].str.split(' ')
# Out:
# 0    [samira, n]
# 1    [gaurav, k]
# 2     [svara, k]
# Name: full_name, dtype: object

# %%
df_p['full_name'].str.split(' ',expand=True)
# Out:
#         0  1
# 0  samira  n
# 1  gaurav  k
# 2   svara  k

# %%
df_p[['first','last']]=df_p['full_name'].str.split(' ',expand=True)
df_p
# Out:
#          email full_name   first last
# 0  sam@abc.com  samira n  samira    n
# 1   gk@abc.com  gaurav k  gaurav    k
# 2    s@abc.com   svara k   svara    k

# %%
df_p.append({'first':'Tony'},ignore_index=True)
# Out:
#          email full_name   first last
# 0  sam@abc.com  samira n  samira    n
# 1   gk@abc.com  gaurav k  gaurav    k
# 2    s@abc.com   svara k   svara    k
# 3          NaN       NaN    Tony  NaN

# %%
people2={'first':["tina","mina"],
        'last':["nkk","bgk"],
        'email':["tina@abc.com",'mina@abc.com']
       }
df2=pd.DataFrame(people2)

# %%
df2
# Out:
#   first last         email
# 0  tina  nkk  tina@abc.com
# 1  mina  bgk  mina@abc.com

# %%
df_p=df_p.append(df2,ignore_index=True)

# %%
df_p
# Out:
#           email full_name   first last
# 0   sam@abc.com  samira n  samira    n
# 1    gk@abc.com  gaurav k  gaurav    k
# 2     s@abc.com   svara k   svara    k
# 3  tina@abc.com       NaN    tina  nkk
# 4  mina@abc.com       NaN    mina  bgk

# %%
df_p.drop(index=4,inplace=True)

# %%
df_p.drop(index=df_p[df_p['last']=='k'].index)
# Out:
#           email full_name   first last
# 0   sam@abc.com  samira n  samira    n
# 3  tina@abc.com       NaN    tina  nkk

# %% [markdown]
# ### Sorting Data

# %%
df_p.sort_values(by='last',ascending=False)
# Out:
#           email full_name   first last
# 3  tina@abc.com       NaN    tina  nkk
# 0   sam@abc.com  samira n  samira    n
# 1    gk@abc.com  gaurav k  gaurav    k
# 2     s@abc.com   svara k   svara    k

# %%
df_p.sort_values(by=['last','first'],ascending=[False,True],inplace =True)
df_p
# Out:
#           email full_name   first last
# 3  tina@abc.com       NaN    tina  nkk
# 0   sam@abc.com  samira n  samira    n
# 1    gk@abc.com  gaurav k  gaurav    k
# 2     s@abc.com   svara k   svara    k

# %%
df_p.sort_index()
# Out:
#           email full_name   first last
# 0   sam@abc.com  samira n  samira    n
# 1    gk@abc.com  gaurav k  gaurav    k
# 2     s@abc.com   svara k   svara    k
# 3  tina@abc.com       NaN    tina  nkk

# %%
df_p['last'].sort_values()
# Out:
# 1      k
# 2      k
# 0      n
# 3    nkk
# Name: last, dtype: object

# %%
df.sort_values(by=['Country'],inplace=True)

# %%
df.head(25)
# Out:
#                                         MainBranch Hobbyist   Age  \
# Respondent
# 8631        I am a student who is learning to code       No   NaN
# 25001               I am a developer by profession       No   NaN
# 58171       I am a student who is learning to code      Yes  23.0
# 42668               I am a developer by profession      Yes   NaN
# 51509               I am a developer by profession       No  28.0
# 37951       I am a student who is learning to code      Yes   NaN
# 28374               I am a developer by profession      Yes   NaN
# 7616                I am a developer by profession       No  24.0
# 43966       I am a student who is learning to code      Yes  25.0
# 62698               I am a developer by profession      Yes   NaN
# 51532               I am a developer by profession      Yes   NaN
# 36574               I am a developer by profession       No   NaN
# 43946       I am a student who is learning to code      Yes   NaN
# ...

# %%
df[['Country','ConvertedComp']].head(10)
# Out:
#                 Country  ConvertedComp
# Respondent
# 8631        Afghanistan            NaN
# 25001       Afghanistan            NaN
# 58171       Afghanistan            NaN
# 42668       Afghanistan            NaN
# 51509       Afghanistan        20220.0
# 37951       Afghanistan            NaN
# 28374       Afghanistan       130000.0
# 7616        Afghanistan            NaN
# 43966       Afghanistan            NaN
# 62698       Afghanistan            NaN

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 54263    2000000.0
# 5725     2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 1793     2000000.0
# 3072     2000000.0
# 3045     2000000.0
# 1413     2000000.0
# 3261     2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nsmallest(10,'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 35295       I am a developer by profession      Yes   NaN         13  Monthly
# 47357       I am a developer by profession      Yes   NaN          5   Weekly
# 27135       I am a developer by profession       No   NaN         16   Yearly
# 6054        I am a developer by profession      Yes  38.0         15   Yearly
# 60292       I am a developer by profession      Yes   NaN         12   Yearly
# 38813       I am a developer by profession       No   NaN         18  Monthly
# 8470        I am a developer by profession      Yes   NaN          5  Monthly
# 41006       I am a developer by profession      Yes  22.0         17   Yearly
# 15493       I am a developer by profession       No  44.0         17  Monthly
# 57369       I am a developer by profession       No  44.0         18  Monthly
#
#             CompTotal  ConvertedComp      Country        CurrencyDesc  \
# Respondent
# ...
